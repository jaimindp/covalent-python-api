# %%
import requests
import json

# %%
from source.covalent_api import *

# %%
with open('../api_keys.json', 'r') as json_file:
    api_keys = json.load(json_file)

# %%
session = Session(api_key=api_keys['covalent'])

# %%
class_b = ClassB(session)

# %%
class_b.get_aave_v2_network_assets()
# Out:
# https://api.covalenthq.com/v1/1/networks/aave_v2/assets/?&key=ckey_9cda6824fa45468f808ca8c0c0e
# {'data': {'updated_at': '2021-09-15T11:07:53.738710712Z',
#   'items': [{'underlying': {'contract_decimals': 6,
#      'contract_name': 'Tether USD',
#      'contract_ticker_symbol': 'USDT',
#      'contract_address': '0xdac17f958d2ee523a2206206994597c13d831ec7',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xdac17f958d2ee523a2206206994597c13d831ec7.png',
#      'quote_rate': 1.002101},
#     'atoken': {'contract_decimals': 6,
#      'contract_name': 'Aave Interest bearing USDT',
#      'contract_ticker_symbol': 'aUSDT',
#      'contract_address': '0x3ed3b47dd13ec9a98b44e6204a523e766b225811',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aUSDT.svg'},
#     'variable_borrow_apr': 0.03736548,
#     'stable_borrow_apr': 0.11868274,
#     'supply_apy': 0.029093876,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 8,
#      'contract_name': 'Wrapped BTC',
#      'contract_ticker_symbol': 'WBTC',
#      'contract_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 8,
#      'contract_name': 'Aave Interest bearing WBTC',
#      'contract_ticker_symbol': 'aWBTC',
#      'contract_address': '0x9ff58f4ffb29fa2266ab25e75e2a8b3503311656',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aWBTC.svg'},
#     'variable_borrow_apr': 0.006618372,
#     'stable_borrow_apr': 0.038272966,
#     'supply_apy': 0.00029356778,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Wrapped Ether',
#      'contract_ticker_symbol': 'WETH',
#      'contract_address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2.png',
#      'quote_rate': 3417.7961},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing WETH',
#      'contract_ticker_symbol': 'aWETH',
#      'contract_address': '0x030ba81f1c18d280636f32af80b9aad02cf0854e',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aWETH.svg'},
#     'variable_borrow_apr': 0.0053649396,
#     'stable_borrow_apr': 0.036706176,
#     'supply_apy': 0.00022386046,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'yearn.finance',
#      'contract_ticker_symbol': 'YFI',
#      'contract_address': '0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e.png',
#      'quote_rate': 36899.984},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing YFI',
#      'contract_ticker_symbol': 'aYFI',
#      'contract_address': '0x5165d24277cd063f5ac44efd447b27025e888f37',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aYFI.svg'},
#     'variable_borrow_apr': 0.0074664187,
#     'stable_borrow_apr': 0.010666312,
#     'supply_apy': 0.00028670093,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': '0x Protocol Token',
#      'contract_ticker_symbol': 'ZRX',
#      'contract_address': '0xe41d2489571d322189246dafa5ebde1f4699f498',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xe41d2489571d322189246dafa5ebde1f4699f498.png',
#      'quote_rate': 1.0647262},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing ZRX',
#      'contract_ticker_symbol': 'aZRX',
#      'contract_address': '0xdf7ff54aacacbff42dfe29dd6144a69b629f8c9e',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aZRX.svg'},
#     'variable_borrow_apr': 0.0073552607,
#     'stable_borrow_apr': 0.040507514,
#     'supply_apy': 0.00121498,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Uniswap',
#      'contract_ticker_symbol': 'UNI',
#      'contract_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing UNI',
#      'contract_ticker_symbol': 'aUNI',
#      'contract_address': '0xb9d7cb55f463405cdfbe4e90a6d2df01c2b92bf1',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aUNI.svg'},
#     'variable_borrow_apr': 0.009110462,
#     'stable_borrow_apr': 0.015617934,
#     'supply_apy': 0.00042685703,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Aave Token',
#      'contract_ticker_symbol': 'AAVE',
#      'contract_address': '0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing AAVE',
#      'contract_ticker_symbol': 'aAAVE',
#      'contract_address': '0xffc97d72e13e01096502cb8eb52dee56f74dad7b',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aAAVE.svg'},
#     'variable_borrow_apr': 0.0,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 0.0,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Basic Attention Token',
#      'contract_ticker_symbol': 'BAT',
#      'contract_address': '0x0d8775f648430679a709e98d2b0cb6250d2887ef',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x0d8775f648430679a709e98d2b0cb6250d2887ef.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing BAT',
#      'contract_ticker_symbol': 'aBAT',
#      'contract_address': '0x05ec93c0365baaeabf7aeffb0972ea7ecdd39cf1',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aBAT.svg'},
#     'variable_borrow_apr': 0.013917089,
#     'stable_borrow_apr': 0.049881555,
#     'supply_apy': 0.0010703081,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Binance USD',
#      'contract_ticker_symbol': 'BUSD',
#      'contract_address': '0x4fabb145d64652a948d72533023f6e7a623c7c53',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x4fabb145d64652a948d72533023f6e7a623c7c53.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing BUSD',
#      'contract_ticker_symbol': 'aBUSD',
#      'contract_address': '0xa361718326c15715591c299427c62086f69923d9',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aBUSD.svg'},
#     'variable_borrow_apr': 0.03624295,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 0.023643924,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Dai Stablecoin',
#      'contract_ticker_symbol': 'DAI',
#      'contract_address': '0x6b175474e89094c44da98b954eedeac495271d0f',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x6b175474e89094c44da98b954eedeac495271d0f.png',
#      'quote_rate': 1.0027404},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing DAI',
#      'contract_ticker_symbol': 'aDAI',
#      'contract_address': '0x028171bca77440897b824ca71d1c56cac55b68a3',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aDAI.svg'},
#     'variable_borrow_apr': 0.03986694,
#     'stable_borrow_apr': 0.11993347,
#     'supply_apy': 0.028927673,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Enjin Coin',
#      'contract_ticker_symbol': 'ENJ',
#      'contract_address': '0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c.png',
#      'quote_rate': 1.729882},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing ENJ',
#      'contract_ticker_symbol': 'aENJ',
#      'contract_address': '0xac6df26a590f08dcc95d5a4705ae8abbc88509ef',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aENJ.svg'},
#     'variable_borrow_apr': 0.004679059,
#     'stable_borrow_apr': 0.0066843703,
#     'supply_apy': 9.9230405e-05,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Kyber Network Crystal',
#      'contract_ticker_symbol': 'KNC',
#      'contract_address': '0xdd974d5c2e2928dea5f71b9825b8b646686bd200',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xdd974d5c2e2928dea5f71b9825b8b646686bd200.png',
#      'quote_rate': 1.8538538},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing KNC',
#      'contract_ticker_symbol': 'aKNC',
#      'contract_address': '0x39c6b3e42d6a679d7d776778fe880bc9487c2eda',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aKNC.svg'},
#     'variable_borrow_apr': 0.04374024,
#     'stable_borrow_apr': 0.0846753,
#     'supply_apy': 0.013213529,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'ChainLink Token',
#      'contract_ticker_symbol': 'LINK',
#      'contract_address': '0x514910771af9ca656af840dff83e8264ecf986ca',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x514910771af9ca656af840dff83e8264ecf986ca.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing LINK',
#      'contract_ticker_symbol': 'aLINK',
#      'contract_address': '0xa06bc25b5805d5f8d82847d191cb4af5a3e873e0',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aLINK.svg'},
#     'variable_borrow_apr': 0.0009683216,
#     'stable_borrow_apr': 0.031383317,
#     'supply_apy': 1.2548062e-05,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Decentraland MANA',
#      'contract_ticker_symbol': 'MANA',
#      'contract_address': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x0f5d2fb29fb7d3cfee444a200298f468908cc942.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing MANA',
#      'contract_ticker_symbol': 'aMANA',
#      'contract_address': '0xa685a61171bb30d4072b338c80cb7b2c865c873e',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aMANA.svg'},
#     'variable_borrow_apr': 0.013765441,
#     'stable_borrow_apr': 0.049664915,
#     'supply_apy': 0.00081745646,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Maker Token',
#      'contract_ticker_symbol': 'MKR',
#      'contract_address': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing MKR',
#      'contract_ticker_symbol': 'aMKR',
#      'contract_address': '0xc713e5e149d5d0715dcd1c156a020976e7e56b88',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aMKR.svg'},
#     'variable_borrow_apr': 0.0013436497,
#     'stable_borrow_apr': 0.031919498,
#     'supply_apy': 1.290733e-05,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Republic Token',
#      'contract_ticker_symbol': 'REN',
#      'contract_address': '0x408e41876cccdc0f92210600ef50372656052a38',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x408e41876cccdc0f92210600ef50372656052a38.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing REN',
#      'contract_ticker_symbol': 'aREN',
#      'contract_address': '0xcc12abe4ff81c9378d670de1b57f8e0dd228d77a',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aREN.svg'},
#     'variable_borrow_apr': 0.010616297,
#     'stable_borrow_apr': 0.015166138,
#     'supply_apy': 0.0006559603,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Synthetix Network Token',
#      'contract_ticker_symbol': 'SNX',
#      'contract_address': '0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing SNX',
#      'contract_ticker_symbol': 'aSNX',
#      'contract_address': '0x35f6b052c598d933d69a4eec4d04c73a191fe6c2',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aSNX.svg'},
#     'variable_borrow_apr': 0.089715555,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 0.023215463,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Synth sUSD',
#      'contract_ticker_symbol': 'sUSD',
#      'contract_address': '0x57ab1ec28d129707052df4df418d58a2d46d5f51',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x57ab1ec28d129707052df4df418d58a2d46d5f51.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing sUSD',
#      'contract_ticker_symbol': 'aSUSD',
#      'contract_address': '0x6c5024cd4f8a59110119c56f8933403a539555eb',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aSUSD.svg'},
#     'variable_borrow_apr': 0.026128823,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 0.010923446,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'TrueUSD',
#      'contract_ticker_symbol': 'TUSD',
#      'contract_address': '0x0000000000085d4780b73119b644ae5ecd22b376',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x0000000000085d4780b73119b644ae5ecd22b376.png',
#      'quote_rate': 1.0032172},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing TUSD',
#      'contract_ticker_symbol': 'aTUSD',
#      'contract_address': '0x101cc05f4a51c0319f570d5e146a8c625198e636',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aTUSD.svg'},
#     'variable_borrow_apr': 0.03855567,
#     'stable_borrow_apr': 0.119277835,
#     'supply_apy': 0.027832292,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 6,
#      'contract_name': 'USD Coin',
#      'contract_ticker_symbol': 'USDC',
#      'contract_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'quote_rate': 1.0022635},
#     'atoken': {'contract_decimals': 6,
#      'contract_name': 'Aave Interest bearing USDC',
#      'contract_ticker_symbol': 'aUSDC',
#      'contract_address': '0xbcca60bb61934080951369a648fb03df4f96263c',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aUSDC.svg'},
#     'variable_borrow_apr': 0.03932405,
#     'stable_borrow_apr': 0.109662026,
#     'supply_apy': 0.031795822,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Curve DAO Token',
#      'contract_ticker_symbol': 'CRV',
#      'contract_address': '0xd533a949740bb3306d119cc777fa900ba034cd52',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xd533a949740bb3306d119cc777fa900ba034cd52.png',
#      'quote_rate': 2.870422},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing CRV',
#      'contract_ticker_symbol': 'aCRV',
#      'contract_address': '0x8dae6cb04688c62d939ed9b68d32bc62e49970b1',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aCRV.svg'},
#     'variable_borrow_apr': 0.06938957,
#     'stable_borrow_apr': 0.12912795,
#     'supply_apy': 0.024762405,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 2,
#      'contract_name': 'Gemini dollar',
#      'contract_ticker_symbol': 'GUSD',
#      'contract_address': '0x056fd409e1d7a124bd7017459dfea2f387b6d5cd',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x056fd409e1d7a124bd7017459dfea2f387b6d5cd.png',
#      'quote_rate': 1.0084621},
#     'atoken': {'contract_decimals': 2,
#      'contract_name': 'Aave Interest bearing GUSD',
#      'contract_ticker_symbol': 'aGUSD',
#      'contract_address': '0xd37ee7e4f452c6638c96536e68090de8cbcdb583',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aGUSD.svg'},
#     'variable_borrow_apr': 0.036575273,
#     'stable_borrow_apr': 0.07657527,
#     'supply_apy': 0.024079513,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Balancer',
#      'contract_ticker_symbol': 'BAL',
#      'contract_address': '0xba100000625a3754423978a60c9317c58a424e3d',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xba100000625a3754423978a60c9317c58a424e3d.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing BAL',
#      'contract_ticker_symbol': 'aBAL',
#      'contract_address': '0x272f97b7a56a387ae942350bbc7df5700f8a4576',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aBAL.svg'},
#     'variable_borrow_apr': 0.023947883,
#     'stable_borrow_apr': 0.064211264,
#     'supply_apy': 0.0029494346,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'SushiBar',
#      'contract_ticker_symbol': 'xSUSHI',
#      'contract_address': '0x8798249c2e607446efb7ad49ec89dd1865ff4272',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x8798249c2e607446efb7ad49ec89dd1865ff4272.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing xSUSHI',
#      'contract_ticker_symbol': 'aXSUSHI',
#      'contract_address': '0xf256cc7847e919fac9b808cc216cac87ccf2f47a',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aXSUSHI.svg'},
#     'variable_borrow_apr': 0.0004905659,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 1.0055936e-06,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'renFIL',
#      'contract_ticker_symbol': 'renFIL',
#      'contract_address': '0xd5147bc8e386d91cc5dbe72099dac6c9b99276f5',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xd5147bc8e386d91cc5dbe72099dac6c9b99276f5.png',
#      'quote_rate': 86.2166},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing renFIL',
#      'contract_ticker_symbol': 'aRENFIL',
#      'contract_address': '0x514cd6756ccbe28772d4cb81bc3156ba9d1744aa',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aRENFIL.svg'},
#     'variable_borrow_apr': 0.0065807956,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 0.0003217082,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Rai Reflex Index',
#      'contract_ticker_symbol': 'RAI',
#      'contract_address': '0x03ab458634910aad20ef5f1c8ee96f1d6ac54919',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x03ab458634910aad20ef5f1c8ee96f1d6ac54919.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing RAI',
#      'contract_ticker_symbol': 'aRAI',
#      'contract_address': '0xc9bc48c72154ef3e5425641a3c747242112a46af',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aRAI.svg'},
#     'variable_borrow_apr': 0.03192586,
#     'stable_borrow_apr': 0.01596293,
#     'supply_apy': 0.01630817,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 9,
#      'contract_name': 'Ampleforth',
#      'contract_ticker_symbol': 'AMPL',
#      'contract_address': '0xd46ba6d942050d489dbd938a2c909a5d5039a161',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xd46ba6d942050d489dbd938a2c909a5d5039a161.png',
#      'quote_rate': 0.9911644},
#     'atoken': {'contract_decimals': 9,
#      'contract_name': 'Aave Interest bearing AMPL',
#      'contract_ticker_symbol': 'aAMPL',
#      'contract_address': '0x1e6bb68acec8fefbd87d192be09bb274170a0548',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aAMPL.svg'},
#     'variable_borrow_apr': 0.0014265908,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 6.868669e-05,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Paxos Standard',
#      'contract_ticker_symbol': 'PAX',
#      'contract_address': '0x8e870d67f660d95d5be530380d0ec0bd388289e1',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x8e870d67f660d95d5be530380d0ec0bd388289e1.png',
#      'quote_rate': 1.0022635},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing PAX',
#      'contract_ticker_symbol': 'aPAX',
#      'contract_address': '0x2e8f4bdbe3d47d7d7de490437aea9915d930f1a3',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aPAX.svg'},
#     'variable_borrow_apr': 0.03135531,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 0.019908898,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'DefiPulse Index',
#      'contract_ticker_symbol': 'DPI',
#      'contract_address': '0x1494ca1f11d487c2bbe4543e90080aeba4ba3c2b',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x1494ca1f11d487c2bbe4543e90080aeba4ba3c2b.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing DPI',
#      'contract_ticker_symbol': 'aDPI',
#      'contract_address': '0x6f634c6135d2ebd550000ac92f494f9cb8183dae',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aDPI.svg'},
#     'variable_borrow_apr': 4.925385e-05,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 1.3862524e-08,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Frax',
#      'contract_ticker_symbol': 'FRAX',
#      'contract_address': '0x853d955acef822db058eb8505911ed77f175b99e',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x853d955acef822db058eb8505911ed77f175b99e.png',
#      'quote_rate': 1.003694},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing FRAX',
#      'contract_ticker_symbol': 'aFRAX',
#      'contract_address': '0xd4937682df3c8aef4fe912a96a74121c0829e664',
#      'supports_erc': ['erc20'],
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aFRAX.svg'},
#     'variable_borrow_apr': 1.25e-06,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 2.5e-11,
#     'lending_pool_contract': '0x7d2768de32b0b80b7a3454c06bdac94a69ddc7a9',
#     'lending_pool_addresses_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_addresses_provider_registry': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_collateral_manager': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_pool_configurator': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'lending_rate_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'price_oracle': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'pool_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'emergency_admin': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'protocol_data_provider': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'weth_gateway': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5',
#     'collector_contract': '0xb53c1a33016b2dc2ff3653530bff1848a515c8c5'}],
#   'pagination': None},
#  'error': False,
#  'error_message': None,
#  'error_code': None}

# %%
result = requests.get("https://api.covalenthq.com/v1/1/networks/aave/assets/?&key=%s" % (api_keys['covalent']))

result = result.json()
result
# Out:
# {'data': {'updated_at': '2021-09-15T10:59:43.196389559Z',
#   'items': [{'underlying': {'contract_decimals': 18,
#      'contract_name': 'Dai Stablecoin',
#      'contract_ticker_symbol': 'DAI',
#      'contract_address': '0x6b175474e89094c44da98b954eedeac495271d0f',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x6b175474e89094c44da98b954eedeac495271d0f.png',
#      'quote_rate': 1.0068885},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing DAI',
#      'contract_ticker_symbol': 'aDAI',
#      'contract_address': '0xfc1e690f61efd961294b3e1ce3313fbd8aa4f85d',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aDAI.svg'},
#     'variable_borrow_apr': 0.019024482,
#     'stable_borrow_apr': 0.04273527,
#     'supply_apy': 0.00809855,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'TrueUSD',
#      'contract_ticker_symbol': 'TUSD',
#      'contract_address': '0x0000000000085d4780b73119b644ae5ecd22b376',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x0000000000085d4780b73119b644ae5ecd22b376.png',
#      'quote_rate': 1.0092734},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing TUSD',
#      'contract_ticker_symbol': 'aTUSD',
#      'contract_address': '0x4da9b813057d04baef4e5800e36083717b4a0341',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aTUSD.svg'},
#     'variable_borrow_apr': 0.014038711,
#     'stable_borrow_apr': 0.049135488,
#     'supply_apy': 0.0011339658,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 6,
#      'contract_name': 'USD Coin',
#      'contract_ticker_symbol': 'USDC',
#      'contract_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png',
#      'quote_rate': 1.0073656},
#     'atoken': {'contract_decimals': 6,
#      'contract_name': 'Aave Interest bearing USDC',
#      'contract_ticker_symbol': 'aUSDC',
#      'contract_address': '0x9ba00d6856a4edf4665bca2c2309936572473b7e',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aUSDC.svg'},
#     'variable_borrow_apr': 0.06180301,
#     'stable_borrow_apr': 0.07940258,
#     'supply_apy': 0.041917928,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 6,
#      'contract_name': 'Tether USD',
#      'contract_ticker_symbol': 'USDT',
#      'contract_address': '0xdac17f958d2ee523a2206206994597c13d831ec7',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xdac17f958d2ee523a2206206994597c13d831ec7.png',
#      'quote_rate': 1.0087963},
#     'atoken': {'contract_decimals': 6,
#      'contract_name': 'Aave Interest bearing USDT',
#      'contract_ticker_symbol': 'aUSDT',
#      'contract_address': '0x71fc860f7d3a592a4a98740e39db31d25db65ae8',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aUSDT.svg'},
#     'variable_borrow_apr': 0.051608197,
#     'stable_borrow_apr': 0.07066417,
#     'supply_apy': 0.027608452,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Synth sUSD',
#      'contract_ticker_symbol': 'sUSD',
#      'contract_address': '0x57ab1ec28d129707052df4df418d58a2d46d5f51',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x57ab1ec28d129707052df4df418d58a2d46d5f51.png',
#      'quote_rate': 1.0068885},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing sUSD',
#      'contract_ticker_symbol': 'aSUSD',
#      'contract_address': '0x625ae63000f46200499120b906716420bd059240',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aSUSD.svg'},
#     'variable_borrow_apr': 0.042018488,
#     'stable_borrow_apr': 0.14706472,
#     'supply_apy': 0.026907371,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'EthLend',
#      'contract_ticker_symbol': 'LEND',
#      'contract_address': '0x80fb784b7ed66730e8b1dbd9820afd29931aab03',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x80fb784b7ed66730e8b1dbd9820afd29931aab03.png',
#      'quote_rate': 3.9550543},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing LEND',
#      'contract_ticker_symbol': 'aLEND',
#      'contract_address': '0x7d2d3688df45ce7c552e19c27e007673da9204b8',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aLEND.svg'},
#     'variable_borrow_apr': 0.0044461805,
#     'stable_borrow_apr': 0.03635169,
#     'supply_apy': 0.0003238993,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Basic Attention Token',
#      'contract_ticker_symbol': 'BAT',
#      'contract_address': '0x0d8775f648430679a709e98d2b0cb6250d2887ef',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x0d8775f648430679a709e98d2b0cb6250d2887ef.png',
#      'quote_rate': 0.79702073},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing BAT',
#      'contract_ticker_symbol': 'aBAT',
#      'contract_address': '0xe1ba0fb44ccb0d11b80f92f4f8ed94ca3ff51d00',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aBAT.svg'},
#     'variable_borrow_apr': 0.022729704,
#     'stable_borrow_apr': 0.062471006,
#     'supply_apy': 0.0044761575,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Ether',
#      'contract_ticker_symbol': 'ETH',
#      'contract_address': '0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee.png',
#      'quote_rate': 3440.9443},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing ETH',
#      'contract_ticker_symbol': 'aETH',
#      'contract_address': '0x3a3a65aab0dd2a17e3f1947ba16138cd37d08c04',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aETH.svg'},
#     'variable_borrow_apr': 0.0006704538,
#     'stable_borrow_apr': 0.030838067,
#     'supply_apy': 1.1319119e-05,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'ChainLink Token',
#      'contract_ticker_symbol': 'LINK',
#      'contract_address': '0x514910771af9ca656af840dff83e8264ecf986ca',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x514910771af9ca656af840dff83e8264ecf986ca.png',
#      'quote_rate': 30.92736},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing LINK',
#      'contract_ticker_symbol': 'aLINK',
#      'contract_address': '0xa64bd6c70cb9051f6a9ba1f163fdc07e0dfb5f84',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aLINK.svg'},
#     'variable_borrow_apr': 0.003420153,
#     'stable_borrow_apr': 0.03488593,
#     'supply_apy': 7.723575e-05,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'KyberNetwork',
#      'contract_ticker_symbol': 'KNC',
#      'contract_address': '0xdd974d5c2e2928dea5f71b9825b8b646686bd200',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xdd974d5c2e2928dea5f71b9825b8b646686bd200.png',
#      'quote_rate': 1.857807},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing KNC',
#      'contract_ticker_symbol': 'aKNC',
#      'contract_address': '0x9d91be44c06d373a8a226e1f3b146956083803eb',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aKNC.svg'},
#     'variable_borrow_apr': 0.012925477,
#     'stable_borrow_apr': 0.046156846,
#     'supply_apy': 0.0014239979,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Augur',
#      'contract_ticker_symbol': 'REP',
#      'contract_address': '0x1985365e9f78359a9b6ad760e32412f4a445e862',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x1985365e9f78359a9b6ad760e32412f4a445e862.png',
#      'quote_rate': None},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing REP',
#      'contract_ticker_symbol': 'aREP',
#      'contract_address': '0x71010a9d003445ac60c4e6a7017c1e89a477b438',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aREP.svg'},
#     'variable_borrow_apr': 0.0033523631,
#     'stable_borrow_apr': 0.03478909,
#     'supply_apy': 0.00031219542,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Maker Token',
#      'contract_ticker_symbol': 'MKR',
#      'contract_address': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2.png',
#      'quote_rate': 2931.6492},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing MKR',
#      'contract_ticker_symbol': 'aMKR',
#      'contract_address': '0x7deb5e830be29f91e298ba5ff1356bb7f8146998',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aMKR.svg'},
#     'variable_borrow_apr': 0.0026343882,
#     'stable_borrow_apr': 0.033763412,
#     'supply_apy': 5.6561814e-05,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Decentraland Token',
#      'contract_ticker_symbol': 'MANA',
#      'contract_address': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x0f5d2fb29fb7d3cfee444a200298f468908cc942.png',
#      'quote_rate': 0.84424096},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing MANA',
#      'contract_ticker_symbol': 'aMANA',
#      'contract_address': '0x6fce4a401b6b80ace52baaefe4421bd188e76f6f',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aMANA.svg'},
#     'variable_borrow_apr': 0.0056709927,
#     'stable_borrow_apr': 0.03708874,
#     'supply_apy': 0.00039288678,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': '0x Protocol Token',
#      'contract_ticker_symbol': 'ZRX',
#      'contract_address': '0xe41d2489571d322189246dafa5ebde1f4699f498',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xe41d2489571d322189246dafa5ebde1f4699f498.png',
#      'quote_rate': 1.0560167},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing ZRX',
#      'contract_ticker_symbol': 'aZRX',
#      'contract_address': '0x6fb0855c404e09c47c3fbca25f08d4e41f9f062f',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aZRX.svg'},
#     'variable_borrow_apr': 1.5955361,
#     'stable_borrow_apr': 1.655536,
#     'supply_apy': 0.035112802,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Synthetix Network Token',
#      'contract_ticker_symbol': 'SNX',
#      'contract_address': '0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f.png',
#      'quote_rate': 13.3499775},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing SNX',
#      'contract_ticker_symbol': 'aSNX',
#      'contract_address': '0x328c4c80bc7aca0834db37e6600a6c49e12da4de',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aSNX.svg'},
#     'variable_borrow_apr': 0.051112406,
#     'stable_borrow_apr': 0.017593672,
#     'supply_apy': 0.0071940394,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 8,
#      'contract_name': 'Wrapped BTC',
#      'contract_ticker_symbol': 'WBTC',
#      'contract_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599.png',
#      'quote_rate': 47728.707},
#     'atoken': {'contract_decimals': 8,
#      'contract_name': 'Aave Interest bearing WBTC',
#      'contract_ticker_symbol': 'aWBTC',
#      'contract_address': '0xfc4b8ed459e00e5400be803a9bb3954234fd50e3',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aWBTC.svg'},
#     'variable_borrow_apr': 0.0008608785,
#     'stable_borrow_apr': 0.031076098,
#     'supply_apy': 1.991724e-05,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Binance USD',
#      'contract_ticker_symbol': 'BUSD',
#      'contract_address': '0x4fabb145d64652a948d72533023f6e7a623c7c53',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x4fabb145d64652a948d72533023f6e7a623c7c53.png',
#      'quote_rate': 1.0068885},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing BUSD',
#      'contract_ticker_symbol': 'aBUSD',
#      'contract_address': '0x6ee0f7bb50a54ab5253da0667b0dc2ee526c30a8',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aBUSD.svg'},
#     'variable_borrow_apr': 0.02715973,
#     'stable_borrow_apr': 0.060059056,
#     'supply_apy': 0.009321073,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Enjin Coin',
#      'contract_ticker_symbol': 'ENJ',
#      'contract_address': '0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c.png',
#      'quote_rate': 1.7275938},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing ENJ',
#      'contract_ticker_symbol': 'aENJ',
#      'contract_address': '0x712db54daa836b53ef1ecbb9c6ba3b9efb073f40',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aENJ.svg'},
#     'variable_borrow_apr': 0.0021324398,
#     'stable_borrow_apr': 0.0030463426,
#     'supply_apy': 2.923264e-05,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Republic',
#      'contract_ticker_symbol': 'REN',
#      'contract_address': '0x408e41876cccdc0f92210600ef50372656052a38',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x408e41876cccdc0f92210600ef50372656052a38.png',
#      'quote_rate': 0.89480007},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing REN',
#      'contract_ticker_symbol': 'aREN',
#      'contract_address': '0x69948cc03f478b95283f7dbf1ce764d0fc7ec54c',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aREN.svg'},
#     'variable_borrow_apr': 0.0009668149,
#     'stable_borrow_apr': 0.0013811642,
#     'supply_apy': 6.0089856e-06,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'YFI Token',
#      'contract_ticker_symbol': 'YFI',
#      'contract_address': '0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e.png',
#      'quote_rate': 36878.72},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing YFI',
#      'contract_ticker_symbol': 'aYFI',
#      'contract_address': '0x12e51e77daaa58aa0e9247db7510ea4b46f9bead',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aYFI.svg'},
#     'variable_borrow_apr': 0.015925784,
#     'stable_borrow_apr': 0.022751119,
#     'supply_apy': 0.005400407,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Aave Token',
#      'contract_ticker_symbol': 'AAVE',
#      'contract_address': '0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9.png',
#      'quote_rate': 390.50342},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing AAVE',
#      'contract_ticker_symbol': 'aAAVE',
#      'contract_address': '0xba3d9687cf50fe253cd2e1cfeede1d6787344ed5',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aAAVE.svg'},
#     'variable_borrow_apr': 0.0,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 0.0,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'},
#    {'underlying': {'contract_decimals': 18,
#      'contract_name': 'Uniswap',
#      'contract_ticker_symbol': 'UNI',
#      'contract_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984',
#      'supports_erc': None,
#      'logo_url': 'https://logos.covalenthq.com/tokens/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984.png',
#      'quote_rate': 25.299088},
#     'atoken': {'contract_decimals': 18,
#      'contract_name': 'Aave Interest bearing UNI',
#      'contract_ticker_symbol': 'aUNI',
#      'contract_address': '0xb124541127a0a657f056d9dd06188c4f1b0e5aab',
#      'supports_erc': None,
#      'logo_url': 'https://www.covalenthq.com/static/images/safekeep/logos/aave/aUNI.svg'},
#     'variable_borrow_apr': 0.0,
#     'stable_borrow_apr': 0.0,
#     'supply_apy': 0.0,
#     'lending_pool_contract': '0x398ec7346dcd622edc5ae82352f02be94c62d119',
#     'lending_pool_core_contract': '0x3dfd23a6c5e8bbcfc9581d2e864a68feb6a076d3'}],
#   'pagination': None},
#  'error': False,
#  'error_message': None,
#  'error_code': None}

# %%
result = requests.get("https://api.covalenthq.com/v1/1/tokens/0xe4605d46fd0b3f8329d936a8b258d69276cba264\
                         /nft_metadata/123/?&key=%s" % (api_keys['covalent']))

result = result.json()
result
# Out:
# {'data': {'updated_at': '2021-09-15T10:49:41.814468Z',
#   'items': [{'contract_decimals': 0,
#     'contract_name': 'Meme Ltd.',
#     'contract_ticker_symbol': 'MEMES',
#     'contract_address': '0xe4605d46fd0b3f8329d936a8b258d69276cba264',
#     'supports_erc': ['erc20'],
#     'logo_url': 'https://logos.covalenthq.com/tokens/0xe4605d46fd0b3f8329d936a8b258d69276cba264.png',
#     'last_transferred_at': None,
#     'type': 'nft',
#     'balance': None,
#     'balance_24h': None,
#     'quote_rate': None,
#     'quote_rate_24h': None,
#     'quote': None,
#     'quote_24h': None,
#     'nft_data': [{'token_id': '123',
#       'token_balance': '1',
#       'token_url': 'https://api.dontbuymeme.com/memes/123',
#       'supports_erc': ['erc20', 'erc1155'],
#       'token_price_wei': None,
#       'token_quote_rate_eth': None,
#       'original_owner': '0x1532cf8977d51de6a609015a23365cdb25064bc1',
#       'external_data': {'name': 'I wish I was understood',
#        'description': '',
#        'image': 'https://image.mux.com/JhTQTZV02XHkVP01KEltrd3CXjQTIeO9j63thGiJpkDv00/thumbnail.jpg',
#        'image_256': 'https://image-proxy.svc.prod.covalenthq.com/256,fit,png,saRm_nMqmhLQ5CZeUy659HmZxPOYkn3keDxThpkHLk30=/https://image.mux.com/JhTQTZV02XHkVP01KEltrd3CXjQTIeO9j63thGiJpkDv00/thumbnail.jpg',
#        'image_512': 'https://image-proxy.svc.prod.covalenthq.com/512,fit,png,saZu25CXBu6_N5g8H7KbwK0IMsqCEIQ_IMQCnr0tl1B4=/https://image.mux.com/JhTQTZV02XHkVP01KEltrd3CXjQTIeO9j63thGiJpkDv00/thumbnail.jpg',
#        'image_1024': 'https://image-proxy.svc.prod.covalenthq.com/1024,fit,png,sKOafBDTFTB4ZpfCVzm8y-TS00Wf7dI363MaU30m4tk8=/https://image.mux.com/JhTQTZV02XHkVP01KEltrd3CXjQTIeO9j63thGiJpkDv00/thumbnail.jpg',
#        'animation_url': 'https://stream.mux.com/JhTQTZV02XHkVP01KEltrd3CXjQTIeO9j63thGiJpkDv00/high.mp4',
#        'external_url': 'https://dontbuymeme.com/nifty/i-wish-i-was-understood-mt7nnth1',
#        'attributes': [{'trait_type': 'Artist', 'value': 'FEWOCiOUS'},
#         {'trait_type': 'Max Supply', 'value': '100'},
#         {'trait_type': 'type', 'value': 'Pop Surreal'},
#         {'trait_type': 'created',
#          'value': 1609267020,
#          'display_type': 'date'}],
#        'owner': None},
#       'owner': None,
#       'owner_address': '0x87f928cf25b212c627936c790850a9f4a4eb07cb',
#       'burned': False}]}],
#   'pagination': None},
#  'error': False,
#  'error_message': None,
#  'error_code': None}

# %%
# :coding: utf-8
# :copyright: Copyright (c) 2021 Lluis Casals Marsol
# Please see the LICENSE file that should have been included as part of this
# package.

import os
import logging

from covalent_api import url_utils as utils
import covalent_api

logging.basicConfig()
logger = logging.getLogger('Tests')
logger.setLevel(logging.INFO)



args_dict = {
    'chain_id': '1',
    'address': '0x74c1e4b8cae59269ec1d85d3d4f324396048f4ac',
    'block_height': '1',
    'starting_block': '1',
    'ending_block': '3',
    'topic': '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925',
    'token_id': '123',
    'id': 'all',
    'tx_hash': '0x77cff4d41d028c10f5fa1ecbc8c899ce537332e9833d4477bbde110e7bc5b5e6',
    'quote_currency': 'EUR',
    'contract_address': '0xB8c77482e45F1F44dE1745F52C74426C631bDD52',
    'contract_addresses': '0xB8c77482e45F1F44dE1745F52C74426C631bDD52',
    'ticker_symbol': 'ETH'
}

#Test class methods
def test_class(cls, class_methods):
    log_errors = []

    for meth_name in class_methods:
        meth = getattr(cls, meth_name)
        required_args, optional_arguments = utils.get_method_arguments(meth)
        meth_args = {}
        for k, v in args_dict.items():
            if k in required_args:
                meth_args[k] = v
        if meth_name == 'get_all_contract_metadata':
            meth_args['chain_id'] = '56'
        try:
            result = meth(**meth_args)
        except Exception as e:
            raise Exception(
                "Could not execute the method {}. \n Arguments: {} \n Error: {}".format(
                    meth_name, meth_args, e
                )
            )

        if not result:
            log_errors.append({'method_name': meth_name, 'result': result})
            logger.debug("meth: {}".format(meth_name))
            logger.debug("result: {}".format(result))
            logger.debug("Test Error")
            logger.debug("******************************")
            continue
        if isinstance(result, dict):
            if result.get('error'):
                log_errors.append({'method_name': meth_name, 'result': result})
                logger.debug("meth: {}".format(meth_name))
                logger.debug("result: {}".format(result))
                logger.debug("Test Error")
                logger.debug("******************************")
                continue
        else:
            log_errors.append({'method_name': meth_name, 'result': result})
            logger.debug("meth: {}".format(meth_name))
            logger.debug("result: {}".format(result))
            logger.debug("Test Error")
            logger.debug("******************************")
            continue

        logger.debug("meth: {}".format(meth_name))
        logger.debug("result: {}".format(result))
        logger.debug("Test OK")
        logger.debug("******************************")

    print("Class {} test result: ".format(cls))
    if log_errors:
        print("The following errors found:")
        for log_error in log_errors:
            print(
                "{}:\n result: {}".format(
                    log_error.get('method_name'),
                    log_error.get('result')
                )
            )
    else:
        print("No errors found")

    print("################################# \n")
    return log_errors


# Create session
session = covalent_api.Session(
    server_url='https://api.covalenthq.com',
    api_key=os.environ.get('COVALENT_API_KEY')
)

#Test class a
class_a = covalent_api.ClassA(session)
class_a_methods = utils.get_class_methods(covalent_api.ClassA)
errors_a = test_class(class_a, class_a_methods)

#Test class b
class_b = covalent_api.ClassB(session)
class_b_methods = utils.get_class_methods(covalent_api.ClassB)
errors_b = test_class(class_b, class_b_methods)

#Test class pricing
class_prices = covalent_api.Pricing(session)
class_prices_methods = utils.get_class_methods(covalent_api.Pricing)
errors_prices = test_class(class_prices, class_prices_methods)
# Out:
# Class <covalent_api.class_a.ClassA object at 0x7f8e2f80e0a0> test result:
# The following errors found:
# get_token_balances_for_address:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_historical_portfolio_value_over_time:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_transactions:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_erc20_token_transfers:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_a_block:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_log_events_by_contract_address:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_log_events_by_topic_hash:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_external_nft_metadata:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_nft_token_ids:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_nft_transactions:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_changes_in_token_holders_between_two_block_heights:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_token_holders_as_of_a_block_height:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_all_contract_metadata:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_a_transaction:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# #################################
#
# Class <covalent_api.class_b.ClassB object at 0x7f8e2f80e850> test result:
# The following errors found:
# get_sushiswap_address_exchange_liquidity_transactions:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_sushiswap_address_exchange_balances:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_sushiswap_network_assets:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_aave_v2_address_balances:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_aave_address_balances:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_balancer_exchange_address_balances:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_compound_address_activity:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_compound_address_balances:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_curve_address_balances:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_farming_stats:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_marker_address_balances_and_acts:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_uniswap_v1_address_exchange_balances:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_uniswap_v2_address_exchange_liquidity_transactions:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_uniswap_v2_address_exchange_balances:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_aave_v2_network_assets:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_aave_network_assets:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_augur_market_affiliate_fee_divisors:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_compound_network_assets:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_uniswap_v2_network_assets:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# #################################
#
# Class <covalent_api.pricing.Pricing object at 0x7f8e2f82fd90> test result:
# The following errors found:
# get_prices_by_address:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_prices_by_addresses:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_historical_prices_by_ticker_symbol:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_spot_prices:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_price_volatility:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# #################################

# %%
import covalent_api
import json
import os

# %%
os.environ['COVALENT_API_KEY'] = api_keys['covalent']

# %%
session = covalent_api.session.Session(server_url='https://api.covalenthq.com', api_key=api_keys['covalent'], timeout=60)

# %%
class_a = covalent_api.ClassA(session)
class_a_methods = utils.get_class_methods(covalent_api.ClassA)
errors_a = test_class(class_a, class_a_methods)
# Out:
# Class <covalent_api.class_a.ClassA object at 0x7f8e2f80e970> test result:
# The following errors found:
# get_token_balances_for_address:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_historical_portfolio_value_over_time:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_transactions:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_erc20_token_transfers:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_a_block:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_log_events_by_contract_address:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_log_events_by_topic_hash:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_external_nft_metadata:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_nft_token_ids:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_nft_transactions:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_changes_in_token_holders_between_two_block_heights:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_token_holders_as_of_a_block_height:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_all_contract_metadata:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# get_a_transaction:
#  result: {'data': None, 'error': True, 'error_message': 'No API key given (sign up at covalenthq.com/platform)', 'error_code': 401}
# #################################

# %%
pricing = covalent_api.pricing.Pricing(session)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9f8d191b15c0> in <module>
# ----> 1 pricing = covalent_api.pricing.Pricing(session)
#
# NameError: name 'covalent_api' is not defined

# %%
quote_currency = 'ETH'
ticker_symbol = 'ETH/USDT'
pricing.get_historical_prices_by_ticker_symbol(quote_currency, ticker_symbol)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f1c9aeb5a4a3> in <module>
#       1 quote_currency = 'ETH'
#       2 ticker_symbol = 'ETH/USDT'
# ----> 3 pricing.get_historical_prices_by_ticker_symbol(quote_currency, ticker_symbol)
#
# NameError: name 'pricing' is not defined

# %%
class_b = covalent_api.class_b.ClassB(session)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-141e1e5fbc3b> in <module>
# ----> 1 class_b = covalent_api.class_b.ClassB(session)
#
# NameError: name 'covalent_api' is not defined

# %%
class_b.get_aave_network_assets()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d3dade7a0481> in <module>
# ----> 1 class_b.get_aave_network_assets()
#
# NameError: name 'class_b' is not defined

# %%
# Importing the requests library
import requests

# Configuration
API_KEY = "ckey_edc1619f340849c6939fba54856" # This is my apiKey (found from online, not mine)
CURRENCY = "USD" # Will get price in USD
TICKET = "ETH" # Will check price of CQT in this sample
FROM = "2021-07-01" # 
TO = "2021-07-15"
# Document of Covalent API: https://www.co
valenthq.com/docs/api/#get-/v1/pricing/historical/{quote_currency}/{ticker_symbol}/
ENPOINT = "https://api.covalenthq.com/v1/pricing/historical/{}/{}/"
URL = ENPOINT.format(CURRENCY, TICKET) 

# Put your apiKey to Get request
PARAMS = {"key": API_KEY, "from": FROM, "to": TO, "prices-at-asc": "true"}

# Sending GET request and saving the response as response object
response = requests.get(url = URL, params = PARAMS)

# Extracting data in json format
data = response.json()

if (data["error"]):
	# There is error and print error_message to console
	print(data["error_message"])
else:
	name = data["data"]["contract_name"]
	ticket = data["data"]["contract_ticker_symbol"]
	prices = data["data"]["prices"]
	for item in prices:
		# Get date, and price
		date = item["date"]
		price = item["price"]
		# Print price and date
		print("Price of ETH at {}: {} USD".format(date, price))
# Out:
#   File "<ipython-input-6-6d5803642078>", line 11
#     valenthq.com/docs/api/#get-/v1/pricing/historical/{quote_currency}/{ticker_symbol}/
#                           ^
# SyntaxError: invalid syntax
